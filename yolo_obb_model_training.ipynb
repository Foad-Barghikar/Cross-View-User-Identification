# %%
pip install ultralytics

# %%
from ultralytics import YOLO
import os

# %%
current_dir = os.getcwd()
dir = current_dir + "\YOLO OBB dataset\data.yaml"

# %%
model = YOLO("yolo11n-obb.pt")
model.train(data=dir, epochs=100, imgsz=512)
